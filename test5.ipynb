# %%
import cv2
import numpy as np
from glob import glob
from models import Yolov4
model = Yolov4(weight_path='./yolov4.weights',
               class_name_path='./class_names/coco_classes.txt')
model.predict('./12ass.jpeg', random_color=True)
# Out:
# nms iou: 0.413 score: 0.3
# all weights read
# load from ./yolov4.weights
# img shape:  (680, 963, 3)
# c:\Users\alamt\anaconda3\envs\tf\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# ...

# %%
reload(models)
from models import Yolov4
model = Yolov4(weight_path='./yolov4.weights',
               class_name_path='./class_names/coco_classes.txt')
model.predict('./12ass.jpeg', random_color=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\alamt\Desktop\python trial3\test5.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alamt/Desktop/python%20trial3/test5.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> reload(models)
#       <a href='vscode-notebook-cell:/c%3A/Users/alamt/Desktop/python%20trial3/test5.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> from models import Yolov4
#       <a href='vscode-notebook-cell:/c%3A/Users/alamt/Desktop/python%20trial3/test5.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> model = Yolov4(weight_path='./yolov4.weights',
#       <a href='vscode-notebook-cell:/c%3A/Users/alamt/Desktop/python%20trial3/test5.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>                class_name_path='./class_names/coco_classes.txt')
#
# NameError: name 'reload' is not defined

# %%
x,y,a,b,c,d,e,f=model.predict('./12ass.jpeg', random_color=True)
print(y)
# Out:
# img shape:  (680, 963, 3)
# # of bboxes: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\alamt\Desktop\python trial3\test5.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alamt/Desktop/python%20trial3/test5.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> x,y,a,b,c,d,e,f=model.predict('./12ass.jpeg', random_color=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/alamt/Desktop/python%20trial3/test5.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> print(type(model.predict('./12ass.jpeg', random_color=True)))
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
from models9 import Yolov4

model5=Yolov4(weight_path='./yolov4.weights',
               class_name_path='./class_names/coco_classes.txt')
p=model5.predict('./thobe3.jpg', random_color=True,plot_img=False)
# Out:
# nms iou: 0.413 score: 0.3
# all weights read
# load from ./yolov4.weights
# img shape:  (900, 600, 3)
# c:\Users\alamt\anaconda3\envs\tf\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# # of bboxes: 1

# %%
person=model5.detect2.loc[model5.detect2["class_name"]=="person"]
height=person["h"]
width=person["w"]
height
# Out:
# 0    815
# Name: h, dtype: int64

# %%
import io, base64
from PIL import Image
base64_str="..."
# Assuming base64_str is the string value without 'data:image/jpeg;base64,'
img = Image.open(io.BytesIO(base64.decodebytes(bytes(base64_str, "utf-8"))))
img.save('my-image.jpeg')
